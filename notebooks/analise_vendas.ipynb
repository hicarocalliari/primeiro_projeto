# %%
import sys
import os

# sys.path.append(os.path.abspath('.')) -> se não criar a pasta notebooks, o caminho para importar as funções de ajuda

sys.path.append(os.path.abspath('..'))  
# Como seu notebook está um nível abaixo, você precisa dizer para o Python subir um nível

import pandas as pd

from utils.funcoes_ajuda import (
    calcular_faturamento,
    limpar_dados,
    formatar_moeda
)
# Out:
# A execução de células com 'Python 3.12.3' requer o pacote ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crie um ambiente Python</a> com os pacotes necessários.
#
# Ou instale 'ipykernel' usando o comando: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
df = pd.read_csv('../data/vendas.csv')
# Os dois pontos sobem para a raiz

# df = pd.read_csv('data/vendas.csv')

'''
'data/vendas.csv': Significa "entre na pasta data que está aqui ao meu lado".

'../data/vendas.csv': Significa "saia da pasta onde estou,
suba um nível, e aí sim procure a pasta data".
'''

# Usando nossa ferramenta de limpeza

df = limpar_dados(df)

print("Dados limpos com sucesso!")
# Out:
# A execução de células com 'Python 3.12.3' requer o pacote ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crie um ambiente Python</a> com os pacotes necessários.
#
# Ou instale 'ipykernel' usando o comando: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
